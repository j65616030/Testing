# %%
# !wget https://www.gutenberg.org/cache/epub/1661/pg1661.txt
# Out:
# --2024-12-13 18:40:59--  https://www.gutenberg.org/cache/epub/1661/pg1661.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 607648 (593K) [text/plain]
# Saving to: ‘pg1661.txt.1’
#
# pg1661.txt.1        100%[===================>] 593.41K  2.43MB/s    in 0.2s
#
# 2024-12-13 18:41:00 (2.43 MB/s) - ‘pg1661.txt.1’ saved [607648/607648]

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 128 # what is the maximum context length for predictions?
max_iters = 10000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 128
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(42)

# wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('pg1661.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)

# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.833378 M parameters
# step 0: train loss 4.7402, val loss 4.7477
# step 100: train loss 2.4933, val loss 2.6746
# step 200: train loss 2.4204, val loss 2.6021
# step 300: train loss 2.3513, val loss 2.5288
# step 400: train loss 2.2499, val loss 2.4344
# step 500: train loss 2.1334, val loss 2.3317
# step 600: train loss 2.0289, val loss 2.2150
# step 700: train loss 1.9436, val loss 2.1432
# step 800: train loss 1.8809, val loss 2.0697
# step 900: train loss 1.8259, val loss 2.0341
# step 1000: train loss 1.7751, val loss 1.9890
# step 1100: train loss 1.7176, val loss 1.9357
# step 1200: train loss 1.6898, val loss 1.9126
# step 1300: train loss 1.6553, val loss 1.8751
# step 1400: train loss 1.6143, val loss 1.8439
# step 1500: train loss 1.5875, val loss 1.8173
# step 1600: train loss 1.5639, val loss 1.8203
# step 1700: train loss 1.5378, val loss 1.8018
# step 1800: train loss 1.5235, val loss 1.7814
# step 1900: train loss 1.5029, val loss 1.7477
# step 2000: train loss 1.4753, val loss 1.7611
# step 2100: train loss 1.4714, val loss 1.7440
# step 2200: train loss 1.4460, val loss 1.7365
# step 2300: train loss 1.4374, val loss 1.7285
# step 2400: train loss 1.4244, val loss 1.7316
# step 2500: train loss 1.4109, val loss 1.6955
# step 2600: train loss 1.3902, val loss 1.6900
# step 2700: train loss 1.3798, val loss 1.7001
# step 2800: train loss 1.3748, val loss 1.7127
# step 2900: train loss 1.3620, val loss 1.6868
# step 3000: train loss 1.3584, val loss 1.7113
# step 3100: train loss 1.3421, val loss 1.6948
# step 3200: train loss 1.3363, val loss 1.6772
# step 3300: train loss 1.3247, val loss 1.6660
# step 3400: train loss 1.3215, val loss 1.6684
# step 3500: train loss 1.3142, val loss 1.6567
# step 3600: train loss 1.3027, val loss 1.6812
# step 3700: train loss 1.2933, val loss 1.6451
# step 3800: train loss 1.2939, val loss 1.6603
# step 3900: train loss 1.2776, val loss 1.6443
# step 4000: train loss 1.2776, val loss 1.6593
# step 4100: train loss 1.2770, val loss 1.6535
# step 4200: train loss 1.2675, val loss 1.6589
# step 4300: train loss 1.2657, val loss 1.6446
# step 4400: train loss 1.2499, val loss 1.6428
# step 4500: train loss 1.2549, val loss 1.6388
# step 4600: train loss 1.2411, val loss 1.6532
# step 4700: train loss 1.2383, val loss 1.6374
# step 4800: train loss 1.2333, val loss 1.6445
# step 4900: train loss 1.2281, val loss 1.6329
# step 5000: train loss 1.2234, val loss 1.6597
# step 5100: train loss 1.2200, val loss 1.6354
# step 5200: train loss 1.2110, val loss 1.6266
# step 5300: train loss 1.2036, val loss 1.6181
# step 5400: train loss 1.2096, val loss 1.6398
# step 5500: train loss 1.2008, val loss 1.6376
# step 5600: train loss 1.1982, val loss 1.6230
# step 5700: train loss 1.1952, val loss 1.6394
# step 5800: train loss 1.1860, val loss 1.6198
# step 5900: train loss 1.1910, val loss 1.6265
# step 6000: train loss 1.1810, val loss 1.6066
# step 6100: train loss 1.1796, val loss 1.6263
# step 6200: train loss 1.1732, val loss 1.6060
# step 6300: train loss 1.1781, val loss 1.6283
# step 6400: train loss 1.1635, val loss 1.6494
# step 6500: train loss 1.1599, val loss 1.6301
# step 6600: train loss 1.1568, val loss 1.6389
# step 6700: train loss 1.1518, val loss 1.6290
# step 6800: train loss 1.1492, val loss 1.6246
# step 6900: train loss 1.1458, val loss 1.6403
# step 7000: train loss 1.1520, val loss 1.6421
# step 7100: train loss 1.1370, val loss 1.6150
# step 7200: train loss 1.1322, val loss 1.6294
# step 7300: train loss 1.1293, val loss 1.6210
# step 7400: train loss 1.1307, val loss 1.6392
# step 7500: train loss 1.1294, val loss 1.6194
# step 7600: train loss 1.1268, val loss 1.6493
# step 7700: train loss 1.1223, val loss 1.6393
# step 7800: train loss 1.1180, val loss 1.6239
# step 7900: train loss 1.1133, val loss 1.6426
# step 8000: train loss 1.1174, val loss 1.6621
# step 8100: train loss 1.1100, val loss 1.6584
# step 8200: train loss 1.1103, val loss 1.6527
# step 8300: train loss 1.1005, val loss 1.6453
# step 8400: train loss 1.1025, val loss 1.6406
# step 8500: train loss 1.0993, val loss 1.6507
# step 8600: train loss 1.0928, val loss 1.6473
# step 8700: train loss 1.0885, val loss 1.6614
# step 8800: train loss 1.0908, val loss 1.6730
# step 8900: train loss 1.0863, val loss 1.6684
# step 9000: train loss 1.0844, val loss 1.6496
# step 9100: train loss 1.0741, val loss 1.6769
# step 9200: train loss 1.0799, val loss 1.6653
# step 9300: train loss 1.0709, val loss 1.6676
# step 9400: train loss 1.0733, val loss 1.6681
# step 9500: train loss 1.0660, val loss 1.6793
# step 9600: train loss 1.0649, val loss 1.6925
# step 9700: train loss 1.0644, val loss 1.6989
# step 9800: train loss 1.0610, val loss 1.6861
# step 9900: train loss 1.0586, val loss 1.6796
# step 9999: train loss 1.0508, val loss 1.6941
#
# As I hopiat it. If you wish to this matter it may have
# addressed to meet ourside yet, at Baker, were this task tried in
# whether I do not discover our them, while gold from his heart, and had turned
# to the shameful with a lampter-expertant expressed. So here’s surprise
# and have heard a
# chance—until the maid, I was planged and this matter in a accompass exame
# reso uparder what are is wexpect.”
#
# “And I know that the pain who is a Cass attempt. As to this bulling his
# extended, and a scert of rand, the punged with his lover enging brild_ and
# bittered of, and then he rose his wrings spotory, however, when she was
# conceing her patches in side. Both had he?” said the lad or oursilly at Lord
# Lord. Backwater to uin imagination to be open, within the depresenteen other
# topic with his arms. He was bluzging, your convemness, that his eyes
# shot and heard an angry to prevent the day, who, you will believe the
# receiver,” said he. “The King is aliver men.”
#
# “So, Doctor; Was now!” said Holmes, could desirected to his dressing-tails
# at me. “Were were there right, to you tell me that of the deep linging
# discover and only visible to her the greath way in London hang. The
# hanker-polic-stoning lip with the land words so seemed to unsee’s enough.
# That, if you, have half returned without tell me this most whistle, but
# his eyes repaid to his umbrace. I must time to go was past, then had
# walking a sup of of valrent in a sleep and rent of a minister of the floor
# of in the wanterpoos later, with a house upon to look down it round the
# letters, nor explaha turty was until we an engagement. Not the
# door of what I came back.”
#
# “Irene you and first,” he, “that you’ll yourself me for this inque change
# I have done that I have notejely musters which have lived news to call
# uplist,” cried I. “The day appakent!”
#
# “Yes, unburged me that you have had died also you will envel?”
#
# “I have the investigate?”
#
# “Oh, it is clear that my privaties has were given. No unnock on a woman
# avere linging in his hands, and

# %%
# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=250)[0].tolist()))
# Out:
# “Oh, would be my own arusive had plouched sounds which armchair, sirpect
# that turness from my suspicious of which he was falled, and possionaly are
# at crosing whichd he grey wire face me an on infermance. Our, there, off
# Losseling-plaperty, as no opt

# %%
# Define la frase inicial
frase_inicial = "sherlock"

# Codifica la frase inicial utilizando el diccionario de tokens
tokens_iniciales = [stoi[c] for c in frase_inicial]

# Crea un tensor que contenga la frase inicial codificada
contexto_inicial = torch.tensor(tokens_iniciales, dtype=torch.long, device=device).unsqueeze(0)

# Genera texto a partir del contexto inicial
print(decode(m.generate(contexto_inicial, max_new_tokens=250)[0].tolist()))
# Out:
# sherlock hes, while he was again. He touched like his occurred
# of water, as the copiising fire the death, and a polimition while
# his eyes.”
#
# “I present it, since you very witn.”
#
# “Brechise about advertise?”
#
# “Not fortune of the yard,” I answered us to smeak
